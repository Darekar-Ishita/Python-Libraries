# %% [markdown]
# ### Pandas
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.

# %% [markdown]
# ### Pandas Series
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series from lists

# %%
# string
country = ['India' , 'Pakistan' , 'USA' , 'Nepal']
pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# dtype: str

# %%
# integer
runs = [31,24,56,100]
pd.Series(runs)
# Out:
# 0     31
# 1     24
# 2     56
# 3    100
# dtype: int64

# %%
#custom index
marks = [67,57,89,100]
subjects = ['Maths' , 'English' ,'Science' , 'Hindi']

pd.Series(marks,index=subjects)
# Out:
# Maths       67
# English     57
# Science     89
# Hindi      100
# dtype: int64

# %%
# setting a name
marks=pd.Series(marks,index=subjects,name='abc')
marks
# Out:
# Maths       67
# English     57
# Science     89
# Hindi      100
# Name: abc, dtype: int64

# %% [markdown]
# #### Series from dict

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}
marks_series = pd.Series(marks,name='ABC')
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: ABC, dtype: int64

# %% [markdown]
# #### Series Attributes

# %%
# size
marks_series.size
# Out:
# 4

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'ABC'

# %%
# is_unique
marks_series.is_unique      #True

pd.Series([1,1,2,3,4,5,6,6]).is_unique
# Out:
# False

# %%
# index
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='str')

# %%
# values
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %% [markdown]
# #### Series using read_csv

# %%
# with one column
subs = pd.read_csv('csv_files/subs.csv').squeeze('columns')
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# series with 2 column
vk = pd.read_csv('csv_files/kohli_ipl.csv',index_col='match_no').squeeze('columns')
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('csv_files/bollywood.csv',index_col='movie').squeeze('columns')
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %% [markdown]
# #### Series Methods

# %%
#head: preview of data(top data is shown)
subs.head()

#for to 2 rows
vk.head(2)

# tail: last 5 rows
vk.tail()

#last 2 matches
vk.tail(2)
# Out:
# match_no
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# randomly show 1 row from data
subs.sample()
movies.sample()
vk.sample()
vk.sample(5)        #random 5 values
# Out:
# match_no
# 96      27
# 212     20
# 43      30
# 110     82
# 120    100
# Name: runs, dtype: int64

# %%
# give the frequency of the data in dataset
movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Tanishaa Mukerji     1
# Tanuja               1
# Ankit                1
# Rakhee Gulzar        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
# sortes the values in asc or desc
# no permenant change in dataset
vk.sort_values()                        #asc
vk.sort_values(ascending=False)         #desc
vk.sort_values(ascending=False).head().values[0]    #method chaining

#change in original dataset permenantely
#vk.sort(inplace=True)
# Out:
# np.int64(113)

# %%
# sort in alphabatic order
movies.sort_index()

#change dataset permenantely
#movies.sort_index(inplace=True)
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: str

# %% [markdown]
# #### Mathematical Method

# %%
# counts the total number of item in series
# dosent count missing values but size counts the missing values
vk.count()
# Out:
# np.int64(215)

# %%
# sum
subs.sum()
# Out:
# np.int64(49510)

# %%
# multiply all item
subs.product()
# Out:
# np.int64(0)

# %%
# mean median mode std variance
subs.mean()             #np.float64(135.64383561643837)
vk.median()             #np.float64(24.0)
print(movies.mode())    #Akshay Kumar
print(subs.std())       #62.6750230372527
vk.var()                #np.float64(688.0024777222343)
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: str
# 62.6750230372527
# np.float64(688.0024777222343)

# %%
#min/max
subs.max()      #396
vk.min()        #0
# Out:
# np.int64(0)

# %%
# summary 
vk.describe()
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# #### Series Indexing

# %%
# Integer indexing
x = pd.Series([12,13,14,15,16,17,79,9])
x[0]
x[2]
# Out:
# np.int64(14)

# %%
#negative indexing: does not work
#x[-1]

# %%
# Slicing
vk[5:16]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
# Negative slicing
vk[-5:]
movies[-5:]
movies[::2]
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# The Accidental Prime Minister (film)         Anupam Kher
# Evening Shadows                         Mona Ambegaonkar
# Fraud Saiyaan                               Arshad Warsi
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
#                                               ...
# Raaz (2002 film)                              Dino Morea
# Waisa Bhi Hota Hai Part II                  Arshad Warsi
# Kaante                                  Amitabh Bachchan
# Aankhen (2002 film)                     Amitabh Bachchan
# Company (film)                                Ajay Devgn
# Name: lead, Length: 750, dtype: str

# %%
# Fancy indexing
vk[[1,3,4,5]]
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
# indexing with labels(if custom index is provided)
movies['2 States (2014 film)']
# Out:
# 'Arjun Kapoor'

# %% [markdown]
# #### Editing Series

# %%
# Using indexing
marks_series['english']=100     #because in previous code we changed the index as subject otherwise marks_series[1]=100 
marks_series
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# Name: ABC, dtype: int64

# %%
# What if index does not exist
# It adds the new value
marks_series['sst'] = 90
marks_series
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# sst         90
# Name: ABC, dtype: int64

# %%
# Slicing
runs_ser=pd.Series(runs)
runs_ser[2:4]=[100,100]
runs_ser
# Out:
# 0     31
# 1     24
# 2    100
# 3    100
# dtype: int64

# %%
# fancy indexing
#runs_ser[[0,3,4]] = [0,0,0]
#runs_ser

# %%
# using index label
movies['Why Cheat India']='Alia Bhatt'
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                               Alia Bhatt
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %% [markdown]
# #### Copy and View

# %% [markdown]
# #### Series with Python Functionalities

# %%
# len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))
# Out:
# 365
# <class 'pandas.Series'>
# ...

# %%
# type conversion
list(marks_series)

dict(marks_series)
# Out:
# {'maths': np.int64(67),
#  'english': np.int64(100),
#  'science': np.int64(89),
#  'hindi': np.int64(100),
#  'sst': np.int64(90)}

# %%
# membership operator

'2 States (2014 film)' in movies

'Alia Bhatt' in movies.values
# Out:
# True

# %%
# looping
for i in movies.index:
  print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
# Arithmetic Operators(Broadcasting)
100 + marks_series
# Out:
# maths      167
# english    200
# science    189
# hindi      200
# sst        190
# Name: ABC, dtype: int64

# %%
# Relational Operators

vk >= 50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# #### Boolean Indexing on Series

# %%
# Find no of 50's and 100's scored by kohli
vk[vk >= 50].size
# Out:
# 50

# %%
# find number of ducks
vk[vk == 0].size
# Out:
# 9

# %%
# Count number of day when I had more than 200 subs a day
subs[subs > 200].size
# Out:
# 59

# %%
# find actors who have done more than 20 movies
num_movies = movies.value_counts()
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Name: count, dtype: int64

# %% [markdown]
# #### Plotting Graphs on Series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: >

# %% [markdown]
# #### Some Important Series Methods

# %%
# astype
import sys
sys.getsizeof(vk)       #1884
sys.getsizeof(vk.astype('int16'))
# Out:
# 594

# %%
# between
vk[vk.between(51,99)].size
# Out:
# 43

# %%
# clip
subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# drop_duplicates
temp = pd.Series([1,1,2,2,3,3,4,4])
temp

temp.drop_duplicates(keep='last')

temp.duplicated().sum()

vk.duplicated().sum()

movies.drop_duplicates()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                               Alia Bhatt
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Sssshhh...                              Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                  Tanuja
# Right Here Right Now (film)                        Ankit
# Talaash: The Hunt Begins...                Rakhee Gulzar
# The Pink Mirror                          Edwin Fernandes
# Name: lead, Length: 566, dtype: str

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.size
# Out:
# 10

# %%
temp.count()
# Out:
# np.int64(7)

# %%
# isnull
temp.isnull().sum()
# Out:
# np.int64(3)

# %%
# dropna
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna
temp.fillna(temp.mean())
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
# isin
vk[(vk == 49) | (vk == 99)]
#OR
vk[vk.isin([49,99])]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
# apply
movies
movies.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                            ALIA
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: str

# %%
#subs
subs.apply(lambda x:'good day' if x > subs.mean() else 'bad day')
subs.mean()
# Out:
# np.float64(135.64383561643837)

# %%
# copy
vk
new = vk.head()
new
new[1] = 1
new = vk.head().copy()
new[1] = 100
new
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64
